# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# #### INTRODUCTION

# %% [markdown]
# WeRateDogs is a Twitter account that rates people's dogs with  comments about the dog. These ratings almost always have a denominator of 10 and numerators always greater than 10. 11/10, 12/10, 13/10.
# This project shows the data wrangling efforts of the twitter account that is the Insights gathered from the data and the
# The project involved the tables gathered using different methods

# %% [markdown]
# ### Insights:
# 1.The most common name are
#     a)Charlie      12
#
#     b)Lucy         11
#
#     c)Oliver       11
#
#     d)Cooper       11
#
#     e)Penny        10
#
#     f)Tucker       10
#
#     g)Lola         10
# 2.The mean rating numerator for the dogs  is 12.
#
# 3.The least common stage for the dogs is floofer with pupper having the highest count of 138

# %% [markdown]
# #### VIsualizations

# %% [markdown]
# The graph shows a bar plot of the distribution of the types  of the dogs that is
#     a)pupper
#     b)doggo
#     c)puppo
#     d)doggo pupper
#     e)floofer

# %% [markdown]
# ![graph.png](attachment:graph.png)

# %% [markdown]
# The plot shows the relationships of the columns and their correlation to each other which would help in establishing the importance of each column to understand more on the rating of the dogs.
# Most of the dogs rated and their confidence intervals are highly correlated with the rating numerator
# while the image num has a low correlation with most of the chosen column hence could not be significant

# %% [markdown]
# ![corr.png](attachment:corr.png)

# %% [markdown]
# The below graphs show the numerical columns and their distributions of the twitter_archive_master dataset
# The p2 and p3 confidence interval columns seem to be left skewed while the pi conf colum sem to be rightly skewed.
# The rating numerator seems to range between 0 and 250 while the denominator seem to range between 0 and 25

# %% [markdown]
# ![bar.png](attachment:bar.png)
